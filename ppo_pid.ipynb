# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from stable_baselines3.common.monitor import Monitor
import matplotlib.pyplot as plt
import pandas as pd

class LineFollowingCarEnv(gym.Env):
    def __init__(self):
        super(LineFollowingCarEnv, self).__init__()

        # Observation space: position error and angle to the line
        self.observation_space = spaces.Box(
            low=np.array([-10.0, -np.pi]),  # Min error and angle
            high=np.array([10.0, np.pi]),  # Max error and angle
            dtype=np.float32
        )

        # Action space: PID gains [Kp, Ki, Kd]
        self.action_space = spaces.Box(
            low=np.array([0.0, 0.0, 0.0]),  # Min gains
            high=np.array([10.0, 10.0, 10.0]),  # Max gains
            dtype=np.float32
        )

        self.reset()

    def reset(self, seed=None, options=None):
        # Set the seed for reproducibility
        if seed is not None:
            np.random.seed(seed)

        # Reset position error and angle
        self.position_error = np.random.uniform(-2.0, 2.0)
        self.angle_to_line = np.random.uniform(-np.pi / 4, np.pi / 4)
        self.time_step = 0
        self.total_error = 0.0  # Accumulated error for reward calculation

        # Return the initial observation and info dictionary
        return np.array([self.position_error, self.angle_to_line], dtype=np.float32), {}

    def step(self, action):
        Kp, Ki, Kd = action  # Extract PID parameters

        # PID control logic
        correction = (
            Kp * self.position_error +
            Ki * self.total_error +
            Kd * (self.position_error - self.prev_position_error if self.time_step > 0 else 0)
        )

        # Update position error and angle based on correction
        self.prev_position_error = self.position_error
        self.position_error -= correction * np.cos(self.angle_to_line)
        self.angle_to_line -= correction * 0.1  # Simplified angular adjustment

        # Keep within bounds
        self.position_error = np.clip(self.position_error, -10, 10)
        self.angle_to_line = np.clip(self.angle_to_line, -np.pi, np.pi)

        # Calculate reward (negative of absolute error)
        reward = -abs(self.position_error)

        # Accumulate error for Ki term
        self.total_error += self.position_error

        # End the episode after 200 timesteps or if error exceeds bounds
        self.time_step += 1
        done = self.time_step >= 200 or abs(self.position_error) > 10

        return (
            np.array([self.position_error, self.angle_to_line], dtype=np.float32),
            reward,
            done,
            False,
            {}
        )

# %%
from stable_baselines3 import PPO

log_dir = "./logs/"

# Create the environment
env = LineFollowingCarEnv()
env = Monitor(env, log_dir + "pid_monitor.csv")

# Train PPO
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=1000000)

# Save the model
model.save("ppo_pid_car")
print("Model saved.")
# Out:
# d:\Reinforcement_Learning\ai_rl\lib\site-packages\gymnasium\spaces\box.py:235: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# d:\Reinforcement_Learning\ai_rl\lib\site-packages\gymnasium\spaces\box.py:305: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.57e+03 |
# | time/              |           |
# |    fps             | 3718      |
# |    iterations      | 1         |
# |    time_elapsed    | 0         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.33e+03    |
# | time/                   |              |
# |    fps                  | 1968         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0020238846 |
# |    clip_fraction        | 0.00679      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | -0.000898    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.12e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00153     |
# |    std                  | 0.998        |
# |    value_loss           | 1.81e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.25e+03    |
# | time/                   |              |
# |    fps                  | 1708         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0037193703 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.0985      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.43e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00266     |
# |    std                  | 1            |
# |    value_loss           | 1.12e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.25e+03    |
# | time/                   |              |
# |    fps                  | 1575         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0029350994 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.00609     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.42e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00234     |
# |    std                  | 1            |
# |    value_loss           | 1.06e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.16e+03   |
# | time/                   |             |
# |    fps                  | 1516        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004424502 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | -0.00144    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.54e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00281    |
# |    std                  | 1.01        |
# |    value_loss           | 1.38e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 1483         |
# |    iterations           | 6            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0025184988 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | -0.000635    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.04e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00142     |
# |    std                  | 1.01         |
# |    value_loss           | 7.43e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.14e+03   |
# | time/                   |             |
# |    fps                  | 1446        |
# |    iterations           | 7           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005551498 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | -0.000901   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.54e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00452    |
# |    std                  | 1.02        |
# |    value_loss           | 1.19e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.11e+03   |
# | time/                   |             |
# |    fps                  | 1441        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005120552 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | -0.000531   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.6e+03     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00392    |
# |    std                  | 1.03        |
# |    value_loss           | 9.21e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 1429         |
# |    iterations           | 9            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0044413717 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | -0.000112    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.28e+03     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00512     |
# |    std                  | 1.02         |
# |    value_loss           | 8.64e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.05e+03   |
# | time/                   |             |
# |    fps                  | 1431        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004589567 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | -8.27e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.88e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00487    |
# |    std                  | 1.03        |
# |    value_loss           | 6.94e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -999       |
# | time/                   |            |
# |    fps                  | 1429       |
# |    iterations           | 11         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00365915 |
# |    clip_fraction        | 0.0294     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.34      |
# |    explained_variance   | -5.2e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.53e+03   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00323   |
# |    std                  | 1.03       |
# |    value_loss           | 7.83e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.02e+03   |
# | time/                   |             |
# |    fps                  | 1416        |
# |    iterations           | 12          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005184514 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | -0.000115   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.94e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00222    |
# |    std                  | 1.02        |
# |    value_loss           | 9.73e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -987         |
# | time/                   |              |
# |    fps                  | 1394         |
# |    iterations           | 13           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0053724153 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.3         |
# |    explained_variance   | -0.000731    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.53e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00291     |
# |    std                  | 1.02         |
# |    value_loss           | 1.15e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -947        |
# | time/                   |             |
# |    fps                  | 1377        |
# |    iterations           | 14          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.002941439 |
# |    clip_fraction        | 0.0158      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | -3.73e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.32e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00211    |
# |    std                  | 1.01        |
# |    value_loss           | 7.99e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -941        |
# | time/                   |             |
# |    fps                  | 1363        |
# |    iterations           | 15          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004586952 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | -2.28e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.93e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00321    |
# |    std                  | 1.01        |
# |    value_loss           | 6.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -911        |
# | time/                   |             |
# |    fps                  | 1365        |
# |    iterations           | 16          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007228516 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | -7.99e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.79e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00356    |
# |    std                  | 1.02        |
# |    value_loss           | 5.02e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -907        |
# | time/                   |             |
# |    fps                  | 1367        |
# |    iterations           | 17          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.004004547 |
# |    clip_fraction        | 0.0256      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | -1.26e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.97e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00283    |
# |    std                  | 1.02        |
# |    value_loss           | 8.84e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -899         |
# | time/                   |              |
# |    fps                  | 1370         |
# |    iterations           | 18           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0028133453 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | -1.2e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.15e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00201     |
# |    std                  | 1.02         |
# |    value_loss           | 6.89e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -910        |
# | time/                   |             |
# |    fps                  | 1360        |
# |    iterations           | 19          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.003981908 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | -8.7e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.28e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00572    |
# |    std                  | 1.03        |
# |    value_loss           | 5.84e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -862        |
# | time/                   |             |
# |    fps                  | 1355        |
# |    iterations           | 20          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004880875 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | -3.22e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.03e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00279    |
# |    std                  | 1.02        |
# |    value_loss           | 6.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -809        |
# | time/                   |             |
# |    fps                  | 1353        |
# |    iterations           | 21          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008670505 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 3.4e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.75e+03    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.000991    |
# |    std                  | 1.03        |
# |    value_loss           | 5.63e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -804        |
# | time/                   |             |
# |    fps                  | 1352        |
# |    iterations           | 22          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005337896 |
# |    clip_fraction        | 0.026       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 1.32e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000738   |
# |    std                  | 1.03        |
# |    value_loss           | 4.98e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -774         |
# | time/                   |              |
# |    fps                  | 1349         |
# |    iterations           | 23           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0036643476 |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | -0.000517    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.74e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00184     |
# |    std                  | 1.03         |
# |    value_loss           | 1e+04        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -832         |
# | time/                   |              |
# |    fps                  | 1351         |
# |    iterations           | 24           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0111520775 |
# |    clip_fraction        | 0.0564       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.35        |
# |    explained_variance   | -5.36e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7e+03      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.00183      |
# |    std                  | 1.03         |
# |    value_loss           | 5.05e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -835       |
# | time/                   |            |
# |    fps                  | 1352       |
# |    iterations           | 25         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.00288868 |
# |    clip_fraction        | 0.00752    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.34      |
# |    explained_variance   | -3.1e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.59e+03   |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00267   |
# |    std                  | 1.03       |
# |    value_loss           | 9.32e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -764        |
# | time/                   |             |
# |    fps                  | 1352        |
# |    iterations           | 26          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.001479359 |
# |    clip_fraction        | 0.00332     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | -7.75e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.18e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00194    |
# |    std                  | 1.03        |
# |    value_loss           | 6.46e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -777         |
# | time/                   |              |
# |    fps                  | 1353         |
# |    iterations           | 27           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0035395338 |
# |    clip_fraction        | 0.0429       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | 5.96e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.000498     |
# |    std                  | 1.03         |
# |    value_loss           | 3.08e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -781        |
# | time/                   |             |
# |    fps                  | 1355        |
# |    iterations           | 28          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.003375173 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | -2.12e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.29e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00243    |
# |    std                  | 1.03        |
# |    value_loss           | 7.57e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -753         |
# | time/                   |              |
# |    fps                  | 1358         |
# |    iterations           | 29           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0030957088 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | 1e-05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.94e+03     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00241     |
# |    std                  | 1.03         |
# |    value_loss           | 5.87e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -803        |
# | time/                   |             |
# |    fps                  | 1359        |
# |    iterations           | 30          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004952628 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | -0.00779    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.26e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00102     |
# |    std                  | 1.02        |
# |    value_loss           | 5.11e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -790          |
# | time/                   |               |
# |    fps                  | 1359          |
# |    iterations           | 31            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00043480782 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.33         |
# |    explained_variance   | 8.34e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.07e+03      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000598     |
# |    std                  | 1.02          |
# |    value_loss           | 7.99e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -751        |
# | time/                   |             |
# |    fps                  | 1361        |
# |    iterations           | 32          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004155849 |
# |    clip_fraction        | 0.0196      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.55e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00205    |
# |    std                  | 1.02        |
# |    value_loss           | 5.98e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -739         |
# | time/                   |              |
# |    fps                  | 1360         |
# |    iterations           | 33           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0043993914 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.31        |
# |    explained_variance   | -9.54e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.99e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000254    |
# |    std                  | 1.02         |
# |    value_loss           | 4.38e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -698         |
# | time/                   |              |
# |    fps                  | 1362         |
# |    iterations           | 34           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0029234607 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.29        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.00103      |
# |    std                  | 1.01         |
# |    value_loss           | 4.93e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -695         |
# | time/                   |              |
# |    fps                  | 1360         |
# |    iterations           | 35           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0010762622 |
# |    clip_fraction        | 0.002        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.29        |
# |    explained_variance   | -0.305       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.06e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000771    |
# |    std                  | 1.01         |
# |    value_loss           | 4.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -698         |
# | time/                   |              |
# |    fps                  | 1362         |
# |    iterations           | 36           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0020864778 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.29        |
# |    explained_variance   | 0.0533       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.99e+03     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00204     |
# |    std                  | 1.01         |
# |    value_loss           | 5.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -671         |
# | time/                   |              |
# |    fps                  | 1365         |
# |    iterations           | 37           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0017673045 |
# |    clip_fraction        | 0.00894      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.29        |
# |    explained_variance   | 0.0529       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.44e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00215     |
# |    std                  | 1.01         |
# |    value_loss           | 4.4e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -712         |
# | time/                   |              |
# |    fps                  | 1366         |
# |    iterations           | 38           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0022571962 |
# |    clip_fraction        | 0.00864      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.0609       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77e+03     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00272     |
# |    std                  | 1.01         |
# |    value_loss           | 6.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -690         |
# | time/                   |              |
# |    fps                  | 1364         |
# |    iterations           | 39           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0010633916 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.0702       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.82e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00105     |
# |    std                  | 1.01         |
# |    value_loss           | 7.76e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -640         |
# | time/                   |              |
# |    fps                  | 1366         |
# |    iterations           | 40           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0028576483 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.0804       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.48e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0033      |
# |    std                  | 1.01         |
# |    value_loss           | 4.73e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -651         |
# | time/                   |              |
# |    fps                  | 1366         |
# |    iterations           | 41           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0027251444 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.0759       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.82e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00277     |
# |    std                  | 1.01         |
# |    value_loss           | 3.99e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -718         |
# | time/                   |              |
# |    fps                  | 1360         |
# |    iterations           | 42           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0033783952 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.081        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.34e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00374     |
# |    std                  | 1.01         |
# |    value_loss           | 6.59e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -720         |
# | time/                   |              |
# |    fps                  | 1355         |
# |    iterations           | 43           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0026386916 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.0655       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.62e+03     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00151     |
# |    std                  | 1.01         |
# |    value_loss           | 7.76e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -717         |
# | time/                   |              |
# |    fps                  | 1355         |
# |    iterations           | 44           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0037150707 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.0862       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.71e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00283     |
# |    std                  | 1.01         |
# |    value_loss           | 5.72e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -685         |
# | time/                   |              |
# |    fps                  | 1355         |
# |    iterations           | 45           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0045816433 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.0592       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.08e+03     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00269     |
# |    std                  | 1.01         |
# |    value_loss           | 5.97e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -786         |
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 46           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0045863446 |
# |    clip_fraction        | 0.0538       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.0681       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.14e+03     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00626     |
# |    std                  | 1.01         |
# |    value_loss           | 5.56e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -764        |
# | time/                   |             |
# |    fps                  | 1356        |
# |    iterations           | 47          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.002251957 |
# |    clip_fraction        | 0.0167      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | 0.0667      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.35e+03    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00167    |
# |    std                  | 1.01        |
# |    value_loss           | 7.88e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -690         |
# | time/                   |              |
# |    fps                  | 1356         |
# |    iterations           | 48           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0042529455 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0717       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62e+03     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00317     |
# |    std                  | 0.997        |
# |    value_loss           | 4.33e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -699       |
# | time/                   |            |
# |    fps                  | 1355       |
# |    iterations           | 49         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.00507089 |
# |    clip_fraction        | 0.0256     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.0728     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.66e+03   |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00483   |
# |    std                  | 1          |
# |    value_loss           | 3.52e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -664         |
# | time/                   |              |
# |    fps                  | 1356         |
# |    iterations           | 50           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0069805137 |
# |    clip_fraction        | 0.0607       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.0711       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.35e+03     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00459     |
# |    std                  | 0.997        |
# |    value_loss           | 5.63e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -600         |
# | time/                   |              |
# |    fps                  | 1355         |
# |    iterations           | 51           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0020020632 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.0649       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.11e+03     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00472     |
# |    std                  | 1            |
# |    value_loss           | 3.91e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -555         |
# | time/                   |              |
# |    fps                  | 1355         |
# |    iterations           | 52           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 106496       |
# ...
# |    value_loss           | 4.19e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -0.127       |
# | time/                   |              |
# |    fps                  | 1238         |
# |    iterations           | 473          |
# |    time_elapsed         | 782          |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0058317864 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.09         |
# |    explained_variance   | 0.62         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00438      |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | 0.000824     |
# |    std                  | 0.182        |
# |    value_loss           | 8.27e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -0.125       |
# | time/                   |              |
# |    fps                  | 1238         |
# |    iterations           | 474          |
# |    time_elapsed         | 783          |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0054561365 |
# |    clip_fraction        | 0.0783       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.09         |
# |    explained_variance   | 0.379        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00476     |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | 0.00145      |
# |    std                  | 0.18         |
# |    value_loss           | 0.000152     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.124      |
# | time/                   |             |
# |    fps                  | 1237        |
# |    iterations           | 475         |
# |    time_elapsed         | 785         |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.006095116 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.12        |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0309     |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.00231    |
# |    std                  | 0.179       |
# |    value_loss           | 5.57e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.144      |
# | time/                   |             |
# |    fps                  | 1237        |
# |    iterations           | 476         |
# |    time_elapsed         | 787         |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.009418335 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.12        |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00802     |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.000994   |
# |    std                  | 0.181       |
# |    value_loss           | 3.87e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -0.137       |
# | time/                   |              |
# |    fps                  | 1237         |
# |    iterations           | 477          |
# |    time_elapsed         | 789          |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0065106973 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.11         |
# |    explained_variance   | 0.739        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00564     |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.00244     |
# |    std                  | 0.18         |
# |    value_loss           | 0.00106      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -0.149       |
# | time/                   |              |
# |    fps                  | 1236         |
# |    iterations           | 478          |
# |    time_elapsed         | 791          |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0063677356 |
# |    clip_fraction        | 0.0992       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.15         |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00548      |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.00109     |
# |    std                  | 0.178        |
# |    value_loss           | 6.46e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.167      |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 479         |
# |    time_elapsed         | 793         |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.005121503 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.16        |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0303     |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00102    |
# |    std                  | 0.177       |
# |    value_loss           | 0.000157    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.164      |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 480         |
# |    time_elapsed         | 794         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.009183941 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.18        |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | 0.000127    |
# |    std                  | 0.176       |
# |    value_loss           | 0.000375    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.174      |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 481         |
# |    time_elapsed         | 796         |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.005937798 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.18        |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00659    |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.000717   |
# |    std                  | 0.176       |
# |    value_loss           | 4.96e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.166      |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 482         |
# |    time_elapsed         | 798         |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.010574863 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.19        |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | 0.000705    |
# |    std                  | 0.175       |
# |    value_loss           | 0.000194    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.172      |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 483         |
# |    time_elapsed         | 799         |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.022401674 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.22        |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0092     |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.000731   |
# |    std                  | 0.172       |
# |    value_loss           | 3.22e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.191      |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 484         |
# |    time_elapsed         | 801         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.016089898 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.26        |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0198     |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | 0.000704    |
# |    std                  | 0.171       |
# |    value_loss           | 0.000129    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -0.201       |
# | time/                   |              |
# |    fps                  | 1236         |
# |    iterations           | 485          |
# |    time_elapsed         | 803          |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0073995823 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.28         |
# |    explained_variance   | 0.753        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0169       |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -0.00164     |
# |    std                  | 0.171        |
# |    value_loss           | 0.000279     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -0.194       |
# | time/                   |              |
# |    fps                  | 1236         |
# |    iterations           | 486          |
# |    time_elapsed         | 805          |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0073633315 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.27         |
# |    explained_variance   | 0.789        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.41e-05     |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00324     |
# |    std                  | 0.172        |
# |    value_loss           | 0.000111     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -0.196       |
# | time/                   |              |
# |    fps                  | 1236         |
# |    iterations           | 487          |
# |    time_elapsed         | 806          |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0052077714 |
# |    clip_fraction        | 0.0721       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.27         |
# |    explained_variance   | 0.62         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0103      |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.0013      |
# |    std                  | 0.171        |
# |    value_loss           | 0.000324     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.196      |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 488         |
# |    time_elapsed         | 808         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.008461352 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.29        |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00812     |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.00386    |
# |    std                  | 0.169       |
# |    value_loss           | 0.000168    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.175      |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 489         |
# |    time_elapsed         | 810         |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.009120916 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.3         |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00963    |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | 0.00104     |
# |    std                  | 0.168       |
# |    value_loss           | 0.000155    |
# -----------------------------------------
# Model saved.

# %%
# Load log data from monitor.csv
log_file = log_dir + "pid_monitor.csv"
log_data = pd.read_csv(log_file, skiprows=1)

# Plot rewards
plt.plot(log_data["r"], label="Episode Reward")
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("Training Rewards")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Load the trained model
model = PPO.load("ppo_pid_car")

# Test and visualize
env = LineFollowingCarEnv()
obs, _ = env.reset()
positions = []
angles = []
done = False

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env.step(action)
    positions.append(obs[0])  # Track position error
    angles.append(obs[1])  # Track angle

# Plot the car's trajectory
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(positions, label="Position Error")
plt.axhline(0, color="r", linestyle="--", label="Target Line")
plt.title("Car Position Error")
plt.xlabel("Timestep")
plt.ylabel("Error")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(angles, label="Angle to Line")
plt.axhline(0, color="r", linestyle="--", label="Aligned")
plt.title("Car Angle to Line")
plt.xlabel("Timestep")
plt.ylabel("Angle (radians)")
plt.legend()

plt.tight_layout()
plt.show()
