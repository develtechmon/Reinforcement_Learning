# %%
import gymnasium as gym

env = gym.make("LunarLander-v3", render_mode="human")
observation, info = env.reset()

episode_over = False
while not episode_over:
    action = env.action_space.sample()  # agent policy that uses the observation and info
    observation, reward, terminated, truncated, info = env.step(action)

    episode_over = terminated or truncated

env.close()

# %% [markdown]
# ### Step 1: Install Required Libraries

# %%
# !pip install stable-baselines3 gymnasium

# %% [markdown]
# ### Step 2: Write the Training Script

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Create and wrap the environment
env = make_vec_env("LunarLander-v3", n_envs=4)  # Parallel environments for faster training

# Define the PPO model
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log="./ppo_lunarlander_tensorboard/")

# Train the agent
timesteps = 1000000  # Adjust as needed
model.learn(total_timesteps=timesteps)

# Save the trained model
model.save("ppo_lunarlander")
env.close()
# Out:
# Using cpu device
# Logging to ./ppo_lunarlander_tensorboard/PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.7     |
# |    ep_rew_mean     | -207     |
# | time/              |          |
# |    fps             | 4008     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95          |
# |    ep_rew_mean          | -171        |
# | time/                   |             |
# |    fps                  | 2260        |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011105313 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00891     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 451         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00766    |
# |    value_loss           | 1.17e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -134        |
# | time/                   |             |
# |    fps                  | 1966        |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009108806 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0517      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 145         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00777    |
# |    value_loss           | 559         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -117        |
# | time/                   |             |
# |    fps                  | 1864        |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011559129 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 196         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 287         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | -85.7       |
# | time/                   |             |
# |    fps                  | 1803        |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010513749 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 295         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 312         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | -71.8        |
# | time/                   |              |
# |    fps                  | 1767         |
# |    iterations           | 6            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0117676575 |
# |    clip_fraction        | 0.159        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 89.2         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0126      |
# |    value_loss           | 325          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | -63.5       |
# | time/                   |             |
# |    fps                  | 1731        |
# |    iterations           | 7           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.014015827 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 78.1        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 220         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | -57.6       |
# | time/                   |             |
# |    fps                  | 1667        |
# |    iterations           | 8           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013848014 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 121         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 210         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | -49.2       |
# | time/                   |             |
# |    fps                  | 1546        |
# |    iterations           | 9           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008018033 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.561       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 123         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00688    |
# |    value_loss           | 169         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 283         |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 1428        |
# |    iterations           | 10          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008830597 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.3        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00724    |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 346         |
# |    ep_rew_mean          | -38.7       |
# | time/                   |             |
# |    fps                  | 1358        |
# |    iterations           | 11          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.013002448 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.9        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00901    |
# |    value_loss           | 85.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 414         |
# |    ep_rew_mean          | -24.8       |
# | time/                   |             |
# |    fps                  | 1298        |
# |    iterations           | 12          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009505704 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.4        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00649    |
# |    value_loss           | 74.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | -20.7       |
# | time/                   |             |
# |    fps                  | 1260        |
# |    iterations           | 13          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.007345414 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00532    |
# |    value_loss           | 82.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 540         |
# |    ep_rew_mean          | -7.87       |
# | time/                   |             |
# |    fps                  | 1210        |
# |    iterations           | 14          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.010586689 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.9        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00643    |
# |    value_loss           | 78.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 596         |
# |    ep_rew_mean          | 3.97        |
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 15          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.009690821 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.3         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 24.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 643         |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 1146        |
# |    iterations           | 16          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.008620305 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.59        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 31.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | 25.1         |
# | time/                   |              |
# |    fps                  | 1130         |
# |    iterations           | 17           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0110782385 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.889        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.44         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00654     |
# |    value_loss           | 25.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 728         |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 1109        |
# |    iterations           | 18          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.009523984 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.53        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00347    |
# |    value_loss           | 32.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 765         |
# |    ep_rew_mean          | 47          |
# | time/                   |             |
# |    fps                  | 1087        |
# |    iterations           | 19          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.008070219 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.915      |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00518    |
# |    value_loss           | 36.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 784          |
# |    ep_rew_mean          | 52           |
# | time/                   |              |
# |    fps                  | 1073         |
# |    iterations           | 20           |
# |    time_elapsed         | 152          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0053260224 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.879       |
# |    explained_variance   | 0.782        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.4         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00388     |
# |    value_loss           | 33.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 820         |
# |    ep_rew_mean          | 59.3        |
# | time/                   |             |
# |    fps                  | 1058        |
# |    iterations           | 21          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.007460766 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.46        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 37.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 834         |
# |    ep_rew_mean          | 65.9        |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 22          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008813582 |
# |    clip_fraction        | 0.0966      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3           |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 15.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 852        |
# |    ep_rew_mean          | 75.4       |
# | time/                   |            |
# |    fps                  | 1039       |
# |    iterations           | 23         |
# |    time_elapsed         | 181        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.01481702 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.877     |
# |    explained_variance   | 0.778      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.81       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00431   |
# |    value_loss           | 36.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 840         |
# |    ep_rew_mean          | 79.4        |
# | time/                   |             |
# |    fps                  | 1029        |
# |    iterations           | 24          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.006535532 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.814      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 34.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 818          |
# |    ep_rew_mean          | 84.4         |
# | time/                   |              |
# |    fps                  | 1026         |
# |    iterations           | 25           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0051177996 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.787       |
# |    explained_variance   | 0.693        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.53         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 62.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 770         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 1026        |
# |    iterations           | 26          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.009383811 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 62.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 702         |
# |    ep_rew_mean          | 126         |
# | time/                   |             |
# |    fps                  | 1027        |
# |    iterations           | 27          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.019016685 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.788      |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 135         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 593         |
# |    ep_rew_mean          | 148         |
# | time/                   |             |
# |    fps                  | 1031        |
# |    iterations           | 28          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.010505455 |
# |    clip_fraction        | 0.0913      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.825      |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.9        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00385    |
# |    value_loss           | 123         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 492         |
# |    ep_rew_mean          | 162         |
# | time/                   |             |
# |    fps                  | 1034        |
# |    iterations           | 29          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.005365829 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97.9        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00133    |
# |    value_loss           | 144         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 415          |
# |    ep_rew_mean          | 174          |
# | time/                   |              |
# |    fps                  | 1038         |
# |    iterations           | 30           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0066871103 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.832       |
# |    explained_variance   | 0.654        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.3         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00362     |
# |    value_loss           | 158          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 388         |
# |    ep_rew_mean          | 171         |
# | time/                   |             |
# |    fps                  | 1036        |
# |    iterations           | 31          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.004301593 |
# |    clip_fraction        | 0.0427      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.7        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0005     |
# |    value_loss           | 149         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | 168         |
# | time/                   |             |
# |    fps                  | 1038        |
# |    iterations           | 32          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.004125045 |
# |    clip_fraction        | 0.0363      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.81       |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.4        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 115         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 371          |
# |    ep_rew_mean          | 172          |
# | time/                   |              |
# |    fps                  | 1040         |
# |    iterations           | 33           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0062281266 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.9         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 131          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 365          |
# |    ep_rew_mean          | 194          |
# | time/                   |              |
# |    fps                  | 1040         |
# |    iterations           | 34           |
# |    time_elapsed         | 267          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0060053905 |
# |    clip_fraction        | 0.0782       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.866       |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.4         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 83.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 361          |
# |    ep_rew_mean          | 192          |
# | time/                   |              |
# |    fps                  | 1043         |
# |    iterations           | 35           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0066284183 |
# |    clip_fraction        | 0.0708       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.833       |
# |    explained_variance   | 0.827        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 88.6         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 57.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | 201          |
# | time/                   |              |
# |    fps                  | 1049         |
# |    iterations           | 36           |
# |    time_elapsed         | 281          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0045228926 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.753       |
# |    explained_variance   | 0.802        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.7         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00272     |
# |    value_loss           | 118          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 342         |
# |    ep_rew_mean          | 203         |
# | time/                   |             |
# |    fps                  | 1053        |
# |    iterations           | 37          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.005865886 |
# |    clip_fraction        | 0.0736      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.733      |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.2        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 116         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 333          |
# |    ep_rew_mean          | 198          |
# | time/                   |              |
# |    fps                  | 1057         |
# |    iterations           | 38           |
# |    time_elapsed         | 294          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0066782143 |
# |    clip_fraction        | 0.0772       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.767       |
# |    explained_variance   | 0.743        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.6         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 108          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 358         |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 1059        |
# |    iterations           | 39          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.011409545 |
# |    clip_fraction        | 0.0732      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 130         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 370          |
# |    ep_rew_mean          | 197          |
# | time/                   |              |
# |    fps                  | 1062         |
# |    iterations           | 40           |
# |    time_elapsed         | 308          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0065464983 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.742       |
# |    explained_variance   | 0.617        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50           |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00096     |
# |    value_loss           | 98.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 390         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 1064        |
# |    iterations           | 41          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.010065541 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.749      |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.29        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 85.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 191         |
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 42          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.004717791 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.736      |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000962   |
# |    value_loss           | 30.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 413          |
# |    ep_rew_mean          | 192          |
# | time/                   |              |
# |    fps                  | 1071         |
# |    iterations           | 43           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 352256       |
# | train/                  |              |
# |    approx_kl            | 0.0030368702 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.73        |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 99.5         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000804    |
# |    value_loss           | 121          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 397          |
# |    ep_rew_mean          | 199          |
# | time/                   |              |
# |    fps                  | 1073         |
# |    iterations           | 44           |
# |    time_elapsed         | 335          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0036069495 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.736       |
# |    explained_variance   | 0.742        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.8         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000471    |
# |    value_loss           | 95.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 399         |
# |    ep_rew_mean          | 204         |
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 45          |
# |    time_elapsed         | 343         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.007118093 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.72       |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 77.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 385          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1077         |
# |    iterations           | 46           |
# |    time_elapsed         | 349          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0043794853 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.697       |
# |    explained_variance   | 0.771        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.4         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 70           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 380          |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 1079         |
# |    iterations           | 47           |
# |    time_elapsed         | 356          |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 0.0048645874 |
# |    clip_fraction        | 0.0617       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.779       |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.4         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00326     |
# |    value_loss           | 63.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 366         |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 1081        |
# |    iterations           | 48          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.004652273 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.8        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00169    |
# |    value_loss           | 88.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 346         |
# |    ep_rew_mean          | 219         |
# | time/                   |             |
# |    fps                  | 1084        |
# |    iterations           | 49          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.005523443 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00225    |
# |    value_loss           | 54.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 355        |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 1085       |
# |    iterations           | 50         |
# |    time_elapsed         | 377        |
# |    total_timesteps      | 409600     |
# | train/                  |            |
# |    approx_kl            | 0.00577767 |
# |    clip_fraction        | 0.0756     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.803     |
# |    explained_variance   | 0.834      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.2       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00208   |
# |    value_loss           | 61.6       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 373          |
# |    ep_rew_mean          | 223          |
# | time/                   |              |
# |    fps                  | 1085         |
# |    iterations           | 51           |
# |    time_elapsed         | 384          |
# |    total_timesteps      | 417792       |
# | train/                  |              |
# |    approx_kl            | 0.0075968215 |
# |    clip_fraction        | 0.0668       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.763       |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.1         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 35.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 391         |
# |    ep_rew_mean          | 224         |
# | time/                   |             |
# |    fps                  | 1086        |
# |    iterations           | 52          |
# |    time_elapsed         | 392         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.006239513 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.743      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.18        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 17.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 406         |
# |    ep_rew_mean          | 224         |
# | time/                   |             |
# |    fps                  | 1087        |
# |    iterations           | 53          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 434176      |
# | train/                  |             |
# |    approx_kl            | 0.010190612 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.73        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 53.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 417          |
# |    ep_rew_mean          | 225          |
# | time/                   |              |
# |    fps                  | 1089         |
# |    iterations           | 54           |
# |    time_elapsed         | 406          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0064279847 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | 0.886        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.3         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 30.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 420          |
# |    ep_rew_mean          | 227          |
# | time/                   |              |
# |    fps                  | 1090         |
# |    iterations           | 55           |
# |    time_elapsed         | 413          |
# |    total_timesteps      | 450560       |
# | train/                  |              |
# |    approx_kl            | 0.0062912637 |
# |    clip_fraction        | 0.0611       |
# ...
# | rollout/                |              |
# |    ep_len_mean          | 307          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 1155         |
# |    iterations           | 106          |
# |    time_elapsed         | 751          |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0037503713 |
# |    clip_fraction        | 0.0368       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.622       |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.26         |
# |    n_updates            | 1050         |
# |    policy_gradient_loss | -0.000528    |
# |    value_loss           | 30.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 1156        |
# |    iterations           | 107         |
# |    time_elapsed         | 757         |
# |    total_timesteps      | 876544      |
# | train/                  |             |
# |    approx_kl            | 0.005431451 |
# |    clip_fraction        | 0.0819      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.07        |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | -0.000668   |
# |    value_loss           | 36.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 290          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 1158         |
# |    iterations           | 108          |
# |    time_elapsed         | 763          |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0068917684 |
# |    clip_fraction        | 0.0955       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.653       |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.58         |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | -0.000912    |
# |    value_loss           | 22           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 299         |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 109         |
# |    time_elapsed         | 770         |
# |    total_timesteps      | 892928      |
# | train/                  |             |
# |    approx_kl            | 0.009286648 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.618      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.3        |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 26.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 293          |
# |    ep_rew_mean          | 261          |
# | time/                   |              |
# |    fps                  | 1160         |
# |    iterations           | 110          |
# |    time_elapsed         | 776          |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0050245156 |
# |    clip_fraction        | 0.0664       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.47         |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 16.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 298         |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 1160        |
# |    iterations           | 111         |
# |    time_elapsed         | 783         |
# |    total_timesteps      | 909312      |
# | train/                  |             |
# |    approx_kl            | 0.006136759 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.614      |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.51        |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | -0.00055    |
# |    value_loss           | 16.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 303         |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 1161        |
# |    iterations           | 112         |
# |    time_elapsed         | 790         |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.008932403 |
# |    clip_fraction        | 0.0587      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.17        |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.000203   |
# |    value_loss           | 29.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 316          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 1161         |
# |    iterations           | 113          |
# |    time_elapsed         | 796          |
# |    total_timesteps      | 925696       |
# | train/                  |              |
# |    approx_kl            | 0.0033099304 |
# |    clip_fraction        | 0.0522       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.593       |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.85         |
# |    n_updates            | 1120         |
# |    policy_gradient_loss | -0.000237    |
# |    value_loss           | 30.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 316         |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 114         |
# |    time_elapsed         | 802         |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.005781737 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.5         |
# |    n_updates            | 1130        |
# |    policy_gradient_loss | 0.000687    |
# |    value_loss           | 10.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 303         |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 115         |
# |    time_elapsed         | 809         |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.005303026 |
# |    clip_fraction        | 0.0511      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.35        |
# |    n_updates            | 1140        |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 19.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 303          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 1164         |
# |    iterations           | 116          |
# |    time_elapsed         | 815          |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0058659213 |
# |    clip_fraction        | 0.0586       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.588       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.68         |
# |    n_updates            | 1150         |
# |    policy_gradient_loss | -0.000499    |
# |    value_loss           | 40.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 289          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 1165         |
# |    iterations           | 117          |
# |    time_elapsed         | 822          |
# |    total_timesteps      | 958464       |
# | train/                  |              |
# |    approx_kl            | 0.0049629267 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.599       |
# |    explained_variance   | 0.943        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.17         |
# |    n_updates            | 1160         |
# |    policy_gradient_loss | -0.000835    |
# |    value_loss           | 40.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 118         |
# |    time_elapsed         | 828         |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.006627325 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.42        |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 17.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 304          |
# |    ep_rew_mean          | 258          |
# | time/                   |              |
# |    fps                  | 1166         |
# |    iterations           | 119          |
# |    time_elapsed         | 835          |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0050122715 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.617       |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.31         |
# |    n_updates            | 1180         |
# |    policy_gradient_loss | -0.000776    |
# |    value_loss           | 16.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 294          |
# |    ep_rew_mean          | 261          |
# | time/                   |              |
# |    fps                  | 1167         |
# |    iterations           | 120          |
# |    time_elapsed         | 841          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0067589534 |
# |    clip_fraction        | 0.0661       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.7          |
# |    n_updates            | 1190         |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 14.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 294         |
# |    ep_rew_mean          | 260         |
# | time/                   |             |
# |    fps                  | 1168        |
# |    iterations           | 121         |
# |    time_elapsed         | 848         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.004587013 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 31.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 307          |
# |    ep_rew_mean          | 256          |
# | time/                   |              |
# |    fps                  | 1168         |
# |    iterations           | 122          |
# |    time_elapsed         | 855          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0054971958 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.55        |
# |    explained_variance   | 0.9          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.5         |
# |    n_updates            | 1210         |
# |    policy_gradient_loss | 0.000432     |
# |    value_loss           | 33.3         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 300       |
# |    ep_rew_mean          | 254       |
# | time/                   |           |
# |    fps                  | 1169      |
# |    iterations           | 123       |
# |    time_elapsed         | 861       |
# |    total_timesteps      | 1007616   |
# | train/                  |           |
# |    approx_kl            | 0.0068654 |
# |    clip_fraction        | 0.0707    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.593    |
# |    explained_variance   | 0.981     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.09      |
# |    n_updates            | 1220      |
# |    policy_gradient_loss | -0.000309 |
# |    value_loss           | 11.9      |
# ---------------------------------------

# %% [markdown]
# ### Step 3: Evaluate the Trained Agent

# %%
from stable_baselines3 import PPO

# Load the trained model
model = PPO.load("ppo_lunarlander")

# Create the environment for evaluation
env = gym.make("LunarLander-v3", render_mode="human")

# Run the trained model in the environment
observation, info = env.reset()
episode_over = False

while not episode_over:
    # Use the trained model to predict actions
    action, _ = model.predict(observation, deterministic=True)
    observation, reward, terminated, truncated, info = env.step(action)
    episode_over = terminated or truncated

env.close()

# %% [markdown]
# ### Step 4: Monitor Training with TensorBoard (Optional)

# %%
tensorboard_log="./ppo_lunarlander_tensorboard/"
